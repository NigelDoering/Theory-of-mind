# %%
import sys
import os


# Get the absolute path to the directory containing 'src'
project_dir = os.path.abspath("..")
sys.path.append(project_dir)

# %%
from src.simulation.simulation_space import DestinationPoint, StartingPoint, SimulationSpace
from src.simulation.agent import Agent
from src.simulation.simulation import Simulation

# %% [markdown]
# ## Create Simulated Trajectory Data

# %%
# Define destination points with the new stopping point logic
destination_1 = DestinationPoint(x=20, y=80, stop_mean=2.0, stop_std=0.5)
destination_2 = DestinationPoint(x=80, y=20, stop_mean=5.0, stop_std=3.0)

# Initialize the simulation space
space = SimulationSpace(size=(100, 100), destination_points=[destination_1, destination_2])

# Add starting points
starting_point_1 = StartingPoint(x=10, y=10, simulation_space=space, position_std=3.0, destination_probs=[0.8, 0.2])
starting_point_2 = StartingPoint(x=90, y=90, simulation_space=space, position_std=8.0, destination_probs=[0.2, 0.8])
space.add_starting_point(starting_point_1)
space.add_starting_point(starting_point_2)

# Create agents
agents = []
for _ in range(500):  # Generate agents
    agent = Agent(simulation_space=space)
    agent.initialize_agent()
    agents.append(agent)

# Add agents to the simulation space
for agent in agents:
    space.add_agent(agent)

# Run the simulation
simulation = Simulation(simulation_space=space, agents=agents)
simulation.run_simulation()

# Visualize the trajectories
simulation.visualize_trajectories()
# Out:
# Simulation complete! All agents have reached their destinations.

# %% [markdown]
# ## K-means on Summary Statistics

# %%
trajectories = simulation.trajectories

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Assuming `trajectories` is a dictionary {id: [(x1, y1), (x2, y2), ...]}
def calculate_summary_stats(trajectories):
    summary_stats = []

    for traj_id, traj in trajectories.items():
        traj = np.array(traj)
        start_point = traj[0]  # Starting point (x1, y1)

        # Calculate direction as the angle of the vector from the first to the second point
        if len(traj) > 1:
            direction_vector = traj[1] - traj[0]
            direction_angle = np.arctan2(direction_vector[1], direction_vector[0])  # Angle in radians
        else:
            direction_angle = 0  # No direction for single-point trajectories

        # Calculate average speed
        if len(traj) > 1:
            distances = np.linalg.norm(np.diff(traj, axis=0), axis=1)
            total_distance = np.sum(distances)
            total_time = len(traj) - 1  # Assuming time steps are uniform
            average_speed = total_distance / total_time
        else:
            average_speed = 0  # No speed for single-point trajectories

        # Append stats to the list
        summary_stats.append({
            "Trajectory ID": traj_id,
            "Start X": start_point[0],
            "Start Y": start_point[1],
            "Direction": direction_angle,
            "Speed": average_speed
        })

    # Convert to a DataFrame
    return pd.DataFrame(summary_stats)

# Calculate summary stats
summary_df = calculate_summary_stats(trajectories)
summary_df.head()
# Out:
#    Trajectory ID     Start X     Start Y  Direction     Speed
# 0              0    9.826807   11.878083   0.195063  1.057653
# 1              1  100.000000   99.559115  -1.593539  1.017890
# 2              2   98.020578   93.557827  -1.980719  0.966946
# 3              3   15.852350    9.942228   1.595485  0.999429
# 4              4   87.700107  100.000000  -2.882103  1.019817

# %%
from sklearn.preprocessing import StandardScaler

# Features for clustering
features = ["Start X", "Start Y", "Direction", "Speed"]

# Normalize the features
scaler = StandardScaler()
normalized_features = scaler.fit_transform(summary_df[features])

# Fit K-Means
kmeans = KMeans(n_clusters=2, n_init=10, random_state=42)
summary_df["Cluster"] = kmeans.fit_predict(normalized_features)

# Display the DataFrame with clusters
print(summary_df.head())
# Out:
#    Trajectory ID     Start X     Start Y  Direction     Speed  Cluster
# 0              0    9.826807   11.878083   0.195063  1.057653        0
# 1              1  100.000000   99.559115  -1.593539  1.017890        1
# 2              2   98.020578   93.557827  -1.980719  0.966946        1
# 3              3   15.852350    9.942228   1.595485  0.999429        0
# 4              4   87.700107  100.000000  -2.882103  1.019817        1

# %%
# Map cluster assignments back to trajectories
trajectory_clusters = {row["Trajectory ID"]: row["Cluster"] for _, row in summary_df.iterrows()}

# %%
import matplotlib.pyplot as plt

# Define colors for the clusters
cluster_colors = {0: "blue", 1: "red"}

plt.figure(figsize=(10, 10))
for traj_id, traj in trajectories.items():
    traj = np.array(traj)
    cluster = trajectory_clusters[traj_id]
    color = cluster_colors[cluster]

    # Plot trajectory
    plt.plot(traj[:, 0], traj[:, 1], color=color, alpha=0.6)

plt.title("Trajectories Clustered by K-Means")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %% [markdown]
# ## DTW with K-means

# %%
def interpolate_trajectory(trajectory, target_length):
    """
    Linearly interpolate a trajectory to a target length.
    Parameters:
        trajectory (list of tuples): Original trajectory [(x1, y1), (x2, y2), ...].
        target_length (int): Desired length of the trajectory.
    Returns:
        np.ndarray: Interpolated trajectory of shape (target_length, 2).
    """
    original_length = len(trajectory)
    trajectory = np.array(trajectory)

    # Create evenly spaced indices for the original and target trajectories
    original_indices = np.linspace(0, original_length - 1, num=original_length)
    target_indices = np.linspace(0, original_length - 1, num=target_length)

    # Interpolate x and y coordinates separately
    x = np.interp(target_indices, original_indices, trajectory[:, 0])
    y = np.interp(target_indices, original_indices, trajectory[:, 1])

    return np.column_stack((x, y))  # Combine x and y into a single array

# Set a target length for all trajectories
target_length = max(len(traj) for traj in trajectories.values())  # Maximum trajectory length

# Interpolate all trajectories to the target length
interpolated_trajectories = [
    interpolate_trajectory(traj, target_length) for traj in trajectories.values()
]
interpolated_trajectories = np.array(interpolated_trajectories)  # Shape: (num_trajectories, target_length, 2)

# %%
import numpy as np
from tslearn.metrics import dtw
from tslearn.clustering import TimeSeriesKMeans

# Convert trajectories dictionary into a list of arrays
trajectory_list = [np.array(trajectory) for trajectory in trajectories.values()]

# Check shape of trajectory data
print(f"Number of trajectories: {len(trajectory_list)}")
print(f"Example trajectory shape: {trajectory_list[0].shape}")
# Out:
# Number of trajectories: 500
# Example trajectory shape: (69, 2)

# %%
# Compute pairwise DTW distances
num_trajectories = len(trajectory_list)
dtw_distances = np.zeros((num_trajectories, num_trajectories))

for i in range(num_trajectories):
    for j in range(num_trajectories):
        dtw_distances[i, j] = dtw(trajectory_list[i], trajectory_list[j])

# Print the distance matrix
print("Pairwise DTW Distance Matrix:")
print(dtw_distances)
# Out:
# Pairwise DTW Distance Matrix:
# [[  0.         622.57903902 584.4183298  ... 634.20651429 741.27760268
#   506.2383307 ]
#  [622.57903902   0.          45.1098884  ...  36.69026325 442.62693503
#    55.20990366]
#  [584.4183298   45.1098884    0.         ...  12.80588335 402.17681064
#    37.43492625]
#  ...
#  [634.20651429  36.69026325  12.80588335 ...   0.         405.43322768
#    52.57425086]
#  [741.27760268 442.62693503 402.17681064 ... 405.43322768   0.
#   435.09817755]
#  [506.2383307   55.20990366  37.43492625 ...  52.57425086 435.09817755
#     0.        ]]

# %%
from tslearn.clustering import TimeSeriesKMeans

# Specify number of clusters
num_clusters = 2

# Apply TimeSeriesKMeans
kmeans = TimeSeriesKMeans(n_clusters=num_clusters, metric="dtw", random_state=42)
cluster_labels = kmeans.fit_predict(interpolated_trajectories)

# Assign cluster labels back to trajectories
trajectory_clusters = {key: cluster_labels[idx] for idx, key in enumerate(trajectories.keys())}

# Print cluster assignments
print("Cluster Assignments:")
print(trajectory_clusters)
# Out:
# Cluster Assignments:
# ...

# %%
import matplotlib.pyplot as plt

# Define colors for clusters
colors = plt.cm.tab10(np.linspace(0, 1, num_clusters))

plt.figure(figsize=(10, 8))
for idx, (traj_id, trajectory) in enumerate(trajectories.items()):
    cluster_id = trajectory_clusters[traj_id]
    plt.plot(*zip(*trajectory), color=colors[cluster_id], label=f"Cluster {cluster_id}" if idx < num_clusters else None)

plt.title("Trajectories Clustered by DTW")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## K-means with Destination Points

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Extract destination points
def extract_destination_points(trajectories):
    """
    Extract destination points (last points) from trajectories.

    Parameters:
        trajectories (dict): Dictionary of trajectories {id: [(x1, y1), (x2, y2), ...]}.

    Returns:
        np.ndarray: Array of destination points, shape (num_trajectories, 2).
    """
    destination_points = np.array([traj[-1] for traj in trajectories.values()])
    return destination_points

destination_points = extract_destination_points(trajectories)
print(f"Destination Points Shape: {destination_points.shape}")
# Out:
# Destination Points Shape: (500, 2)

# %%
# Apply K-Means clustering
num_clusters = 2
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(destination_points)

# Assign cluster labels back to trajectories
trajectory_clusters = {key: cluster_labels[idx] for idx, key in enumerate(trajectories.keys())}

# %%
# Visualize clustered destinations and trajectories
colors = plt.cm.tab10(np.linspace(0, 1, num_clusters))

plt.figure(figsize=(10, 8))

# Plot trajectories with cluster colors
for traj_id, traj in trajectories.items():
    cluster_id = trajectory_clusters[traj_id]
    plt.plot(*zip(*traj), color=colors[cluster_id], alpha=0.7)

# Plot destination points with cluster colors and add to legend
for cluster_id in range(num_clusters):
    plt.scatter(
        destination_points[cluster_labels == cluster_id, 0], 
        destination_points[cluster_labels == cluster_id, 1], 
        c=[colors[cluster_id]], 
        label=f"Cluster {cluster_id}",
        s=100,
        marker="X"
    )

plt.title("Trajectories Clustered by Destination Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc="best")
plt.grid()
plt.show()

# %% [markdown]
# ### VAE with Conditional Goals

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np


class TrajectoryDataset(Dataset):
    def __init__(self, trajectories, trajectory_clusters, max_len):
        """
        Dataset for trajectories with interpolation to uniform length.

        Parameters:
            trajectories (dict): Dictionary of trajectories {id: [(x1, y1), ...]}.
            trajectory_clusters (dict): Dictionary of cluster labels {id: cluster_id}.
            max_len (int): Target length for all trajectories after interpolation.
        """
        self.max_len = max_len
        
        # Prepare data and labels
        interpolated_trajectories = []
        labels = []
        
        for traj_id, traj in trajectories.items():
            # Interpolate trajectory to fixed length
            interpolated_traj = interpolate_trajectory(traj, max_len)
            interpolated_trajectories.append(interpolated_traj)
            labels.append(trajectory_clusters[traj_id])
        
        # Convert to numpy arrays for efficiency
        self.data = np.array(interpolated_trajectories, dtype=np.float32)
        self.labels = np.array(labels, dtype=np.int64)
    
        # Convert to PyTorch tensors
        self.data = torch.tensor(self.data)  # Shape: (num_trajectories, max_len, 2)
        self.labels = torch.tensor(self.labels)  # Shape: (num_trajectories,)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %%
# Define the VAE Model
class ClusterAwareVAE(nn.Module):
    def __init__(self, input_dim, latent_dim, cluster_dim, hidden_dim):
        """
        Variational Autoencoder with cluster-aware latent space.

        Parameters:
            input_dim (int): Input dimension (e.g., 2 for x, y coordinates).
            latent_dim (int): Dimensionality of the latent space.
            cluster_dim (int): Dimensionality of cluster encoding.
            hidden_dim (int): Hidden layer dimension.
        """
        super(ClusterAwareVAE, self).__init__()
        
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim + cluster_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )
        self.mu = nn.Linear(hidden_dim, latent_dim)
        self.log_var = nn.Linear(hidden_dim, latent_dim)
        
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim + cluster_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)  # Predict next step
        )
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def forward(self, x, cluster_onehot):
        """
        Forward pass with cluster information.

        Parameters:
            x (torch.Tensor): Trajectory data, shape (batch_size, seq_len, input_dim).
            cluster_onehot (torch.Tensor): Cluster one-hot encoding, shape (batch_size, cluster_dim).

        Returns:
            recon_x (torch.Tensor): Reconstructed trajectory.
            mu (torch.Tensor): Mean of latent space.
            log_var (torch.Tensor): Log variance of latent space.
        """
        batch_size, seq_len, _ = x.shape
        
        # Flatten sequence for encoding
        x_flat = x.view(batch_size * seq_len, -1)
        cluster_expanded = cluster_onehot.unsqueeze(1).repeat(1, seq_len, 1).view(batch_size * seq_len, -1)
        
        # Encode
        combined_input = torch.cat([x_flat, cluster_expanded], dim=1)
        hidden = self.encoder(combined_input)
        mu = self.mu(hidden)
        log_var = self.log_var(hidden)
        
        # Reparameterize
        z = self.reparameterize(mu, log_var)
        
        # Decode
        z_expanded = z.view(batch_size, seq_len, -1)
        combined_latent = torch.cat([z_expanded, cluster_expanded.view(batch_size, seq_len, -1)], dim=2)
        recon_x = self.decoder(combined_latent.view(batch_size * seq_len, -1))
        
        return recon_x.view(batch_size, seq_len, -1), mu, log_var

# %%
# Define Loss Function
def vae_loss(recon_x, x, mu, log_var):
    recon_loss = nn.MSELoss()(recon_x, x)
    kl_div = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return recon_loss + kl_div

# %%
# Train the VAE
def train_vae(vae, dataloader, num_clusters, num_epochs=20, lr=1e-3):
    optimizer = optim.Adam(vae.parameters(), lr=lr)
    vae.train()
    
    for epoch in range(num_epochs):
        total_loss = 0
        for x, labels in dataloader:
            # Convert labels to one-hot encoding
            cluster_onehot = torch.zeros(x.size(0), num_clusters)
            cluster_onehot.scatter_(1, labels.unsqueeze(1), 1)
            
            # Forward pass
            recon_x, mu, log_var = vae(x, cluster_onehot)
            loss = vae_loss(recon_x, x, mu, log_var)
            
            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
        
        if not epoch%10:
            print(f"Epoch {epoch + 1}, Loss: {total_loss / len(dataloader)}")

# %%
max_len = max(len(traj) for traj in trajectories.values())  # Find the max trajectory length
dataset = TrajectoryDataset(trajectories, trajectory_clusters, max_len=max_len)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

input_dim = 2
latent_dim = 16
cluster_dim = len(set(trajectory_clusters.values()))  # Number of clusters
hidden_dim = 64

vae = ClusterAwareVAE(input_dim, latent_dim, cluster_dim, hidden_dim)
train_vae(vae, dataloader, num_clusters=cluster_dim, num_epochs=100)
# Out:
# Epoch 1, Loss: 3171123.0288085938
# Epoch 11, Loss: 4602.671844482422
# Epoch 21, Loss: 1014.2273864746094
# Epoch 31, Loss: 797.4842987060547
# Epoch 41, Loss: 653.1590824127197
# Epoch 51, Loss: 559.1686592102051
# Epoch 61, Loss: 543.5791130065918
# Epoch 71, Loss: 529.6389961242676
# Epoch 81, Loss: 526.1755809783936
# Epoch 91, Loss: 518.0965595245361

# %% [markdown]
# ### Fit K-means on latent space

# %%
import torch.nn.functional as F

vae.eval()  # Set VAE to evaluation mode
latent_means = []

with torch.no_grad():
    for inputs, cluster_labels in dataloader:  # Use training data
        inputs = inputs.to(device)
        cluster_onehot = F.one_hot(cluster_labels, num_classes=num_clusters).float().to(device)
        
        # Pass through the encoder to get latent space means
        _, mu, _ = vae(inputs, cluster_onehot)
        latent_means.append(mu.cpu().numpy())

latent_means = np.vstack(latent_means)  # Combine all batches into one array
print(f"Latent space projections shape: {latent_means.shape}")
# Out:
# Latent space projections shape: (45000, 16)

# %%
from sklearn.cluster import KMeans

# Fit K-means clustering on latent space
num_clusters = 2  # Number of goals
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(latent_means)

# Store cluster centroids and assign labels to trajectories
latent_cluster_centroids = kmeans.cluster_centers_
latent_cluster_labels = kmeans.labels_

print("Cluster centroids in latent space:", latent_cluster_centroids)
# Out:
# Cluster centroids in latent space: [[-8.2532763e-03  2.7622230e-04 -1.1238998e-02 -1.9446362e-03
#   -1.2738186e-02 -6.6642072e-03 -2.2383673e-02 -4.4816746e-03
#    1.3821722e-02  3.7586200e-05  2.3791883e-03 -1.0284055e-03
#    2.7204095e-03 -1.4798157e-04 -1.7143660e-03  3.0587707e-04]
#  [ 1.0945120e-01 -6.3279332e-03  3.5653576e-02  2.1503555e-02
#   -8.8291243e-04  5.2579433e-02  3.1224962e-02  1.5738135e-02
#   -8.4490396e-02 -7.6369625e-03  4.6747848e-02 -4.7231764e-02
#   -2.5975795e-03 -3.0237399e-02  1.4013333e-02  2.0583441e-02]]

# %%
vae.eval()  # Set the VAE model to evaluation mode
test_reconstruction_loss = 0
mse_loss = nn.MSELoss()  # MSE for trajectory prediction quality
mae_loss = nn.L1Loss()  # MAE for trajectory prediction quality

latent_means = []

with torch.no_grad():  # No gradients needed for evaluation
    for inputs, _ in dataloader:  # Use original training data
        inputs = inputs.to(device)
        
        # Encode the trajectories into the latent space
        batch_size, seq_len, _ = inputs.shape
        inputs_flat = inputs.view(batch_size * seq_len, -1)  # Flatten the sequence
        latent_mu, _ = vae.encoder(inputs_flat).chunk(2, dim=1)  # Get mean (mu)
        latent_mu = latent_mu.view(batch_size, seq_len, -1).mean(dim=1)  # Average over sequence

        # Predict clusters for the latent representations using K-means
        predicted_clusters = kmeans.predict(latent_mu.cpu().numpy())
        
        # Create one-hot encodings for the predicted clusters
        cluster_onehot = torch.zeros(batch_size, num_clusters).to(device)
        cluster_onehot[range(batch_size), predicted_clusters] = 1.0

        # Forward pass with inferred cluster IDs
        recon_targets, _, _ = vae(inputs, cluster_onehot)

        # Compute reconstruction loss
        mse = mse_loss(recon_targets, inputs[:, 1:, :])  # Compare with actual next steps
        mae = mae_loss(recon_targets, inputs[:, 1:, :])

        test_reconstruction_loss += mse.item()

# Average losses
num_batches = len(train_loader)
test_reconstruction_loss /= num_batches
print(f"Test Reconstruction Loss (MSE): {test_reconstruction_loss:.4f}")
print(f"Test Reconstruction Loss (MAE): {mae.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[95], line 15
#      13 batch_size, seq_len, _ = inputs.shape
#      14 inputs_flat = inputs.view(batch_size * seq_len, -1)  # Flatten the sequence
# ---> 15 latent_mu, _ = vae.encoder(inputs_flat).chunk(2, dim=1)  # Get mean (mu)
#      16 latent_mu = latent_mu.view(batch_size, seq_len, -1).mean(dim=1)  # Average over sequence
#      18 # Predict clusters for the latent representations using K-means
#
# File ~/miniconda3/envs/community_detection/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# ...
